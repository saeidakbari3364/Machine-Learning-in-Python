# %% [markdown]
# <a href="https://colab.research.google.com/github/saeidakbari3364/Machine-Learning-in-Python/blob/main/PyCaret02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib as plt
plt.__version__
# Out:
# '3.7.1'

# %%
# !pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.4/60.4 kB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.8/165.8 kB 10.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.1/486.1 kB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 8.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.8/21.8 MB 58.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.0/82.0 kB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.2/302.2 kB 18.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 50.8 MB/s eta 0:00:00
# ...

# %%
from pycaret.regression import *
from pycaret.datasets import get_data
import pandas as pd

# %%
boston=get_data('boston')
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#     black  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
setup(data=boston,target='medv',session_id=123)
# Out:
# <style type="text/css">
# #T_d722e_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d722e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d722e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_d722e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d722e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d722e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_d722e_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_d722e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d722e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d722e_row1_col1" class="data row1 col1" >medv</td>
#     </tr>
#     <tr>
#       <th id="T_d722e_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best=compare_models()
# Out:
# <style type="text/css">
# #T_f087c th {
#   text-align: left;
# }
# ...

# %%
et=create_model('et',n_estimators=300)
# Out:
# <style type="text/css">
# #T_0bd22_row10_col0, #T_0bd22_row10_col1, #T_0bd22_row10_col2, #T_0bd22_row10_col3, #T_0bd22_row10_col4, #T_0bd22_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_0bd22" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0bd22_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_0bd22_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_0bd22_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_0bd22_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_0bd22_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_0bd22_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
plot_model(et)

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
save_model(et,'Mymodelet')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['crim', 'zn', 'indus', 'chas',
#                                               'nox', 'rm', 'age', 'dis', 'rad',
#                                               'tax', 'ptratio', 'black',
#                                               'lstat'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=[],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('trained_model',
#                   ExtraTreesRegressor(n_estimators=300, n_jobs=-1,
#                                       random_state=123))]),
#  'Mymodelet.pkl')

# %%
loaded_model=load_model('Mymodelet')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
predict_model(loaded_model)
# Out:
# <style type="text/css">
# </style>
# <table id="T_24140" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_24140_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_24140_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_24140_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_24140_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_24140_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_24140_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_24140_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_24140_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_24140_row0_col0" class="data row0 col0" >Extra Trees Regressor</td>
#       <td id="T_24140_row0_col1" class="data row0 col1" >2.2346</td>
# ...

# %%
models()
# Out:
#                                        Name  \
# ID
# lr                        Linear Regression
# lasso                      Lasso Regression
# ridge                      Ridge Regression
# en                              Elastic Net
# lar                  Least Angle Regression
# llar           Lasso Least Angle Regression
# omp             Orthogonal Matching Pursuit
# br                           Bayesian Ridge
# ard       Automatic Relevance Determination
# par            Passive Aggressive Regressor
# ransac              Random Sample Consensus
# tr                       TheilSen Regressor
# huber                       Huber Regressor
# kr                             Kernel Ridge
# svm               Support Vector Regression
# knn                   K Neighbors Regressor
# dt                  Decision Tree Regressor
# rf                  Random Forest Regressor
# et                    Extra Trees Regressor
# ada                      AdaBoost Regressor
# ...

# %%
dt=create_model('dt')
# Out:
# <style type="text/css">
# #T_b5f2d_row10_col0, #T_b5f2d_row10_col1, #T_b5f2d_row10_col2, #T_b5f2d_row10_col3, #T_b5f2d_row10_col4, #T_b5f2d_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_b5f2d" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b5f2d_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_b5f2d_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_b5f2d_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_b5f2d_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_b5f2d_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_b5f2d_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
tuned_dt=tune_model(dt)
# Out:
# <style type="text/css">
# #T_36bab_row10_col0, #T_36bab_row10_col1, #T_36bab_row10_col2, #T_36bab_row10_col3, #T_36bab_row10_col4, #T_36bab_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_36bab" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_36bab_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_36bab_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_36bab_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_36bab_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_36bab_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_36bab_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
best1=automl()

# %%
best1
# Out:
# ExtraTreesRegressor(n_estimators=300, n_jobs=-1, random_state=123)

# %%
dashboard(best1)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-27-ec00d46e97ba> in <cell line: 1>()
# ----> 1 dashboard(best1)
#
# /usr/local/lib/python3.10/dist-packages/pycaret/utils/generic.py in wrapper(*args, **kwargs)
#     962                 if globals_d[name] is None:
#     963                     raise ValueError(message)
# --> 964             return func(*args, **kwargs)
#     965
#     966         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/pycaret/regression/functional.py in dashboard(estimator, display_format, dashboard_kwargs, run_kwargs, **kwargs)
#    2709     """
#    2710
# -> 2711     return _CURRENT_EXPERIMENT.dashboard(
#    2712         estimator, display_format, dashboard_kwargs, run_kwargs, **kwargs
#    2713     )
#
# ...

# %%
eda()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-ddf8d70cbef5> in <cell line: 1>()
# ----> 1 eda()
#
# NameError: name 'eda' is not defined
