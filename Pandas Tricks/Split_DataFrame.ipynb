# %% [markdown]
# **Pandas Trick 10**
# <br></br>
# Split DataFrame

# %%
import numpy as np
import pandas as pd

# %%
pd.__version__
# Out:
# '2.1.4'

# %%
df=pd.DataFrame({'name':['saeid akbari','ali ahmadi'],'location':['Tehran ,Iran','Melborn ,Austrlia']})
df.head()
# Out:
#            name           location
# 0  saeid akbari       Tehran ,Iran
# 1    ali ahmadi  Melborn ,Austrlia

# %%
df[['First Name','Last Name']]=df.name.str.split(' ',expand=True)

# %%
df.head()
# Out:
#            name           location First Name Last Name
# 0  saeid akbari       Tehran ,Iran      saeid    akbari
# 1    ali ahmadi  Melborn ,Austrlia        ali    ahmadi

# %%
#another way

# %%
df['city'],df['country']=zip(*df.location.str.split(','))
df.head()
# Out:
#            name           location First Name Last Name      city   country
# 0  saeid akbari       Tehran ,Iran      saeid    akbari   Tehran       Iran
# 1    ali ahmadi  Melborn ,Austrlia        ali    ahmadi  Melborn   Austrlia
