# %% [markdown]
# Pandas Libraray Useful for Data Processing and Analysis
#
# Pandas Data Frame
#
# Pandas Data Frame is two-dimentional tabular data stracture with labeled axes(rows and columns)

# %%
import pandas as pd

# %%
from sklearn.datasets import load_diabetes

# %%
dibetes_db=load_diabetes()

# %%
type(dibetes_db)
# Out:
# sklearn.utils.Bunch

# %%
diabetes_df=pd.DataFrame(dibetes_db.data,columns=dibetes_db.feature_names)

# %%
diabetes_df.describe()
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -3.634285e-16  1.308343e-16 -8.045349e-16  1.281655e-16 -8.835316e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123996e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665645e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670611e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564384e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320442e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   1.327024e-16 -4.574646e-16  3.777301e-16 -3.830854e-16 -3.412882e-16
# ...

# %%
diabetes_df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019908 -0.017646
# 1 -0.039493 -0.068330 -0.092204
# 2 -0.002592  0.002864 -0.025930
# 3  0.034309  0.022692 -0.009362
# 4 -0.002592 -0.031991 -0.046641

# %%
diabetes_df.shape
# Out:
# (442, 10)

# %%
#Importing a csv file into a DataFarme

# %%
df1=pd.read_csv('diabetes.csv')

# %%
df1.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
#Loading the Excel file into a DataFrame

# %%
#df2=pd.read_excel('FilePath')

# %%
#Exporting a Data Frame to a Csv file

# %%
csv_ofdf=df1.to_csv('Name file to save')

# %%
#Exporting a data frame into a Ecxel file

# %%
#excl_ofdf=df1.to_excel('')

# %%
#Create a DataFrame with a Random Values

# %%
import numpy as np

# %%
random_df=pd.DataFrame(np.random.rand(20,10))#20 rows and 10 columns values between zero and one

# %%
random_df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.449305  0.936038  0.121905  0.270253  0.951307  0.140861  0.991917
# 1  0.354717  0.929076  0.959374  0.805908  0.260008  0.247292  0.299366
# 2  0.009724  0.069137  0.409185  0.647526  0.609377  0.473629  0.112789
# 3  0.246166  0.668609  0.364363  0.021767  0.861521  0.841232  0.159485
# 4  0.991778  0.578829  0.908752  0.948493  0.626574  0.389868  0.743600
#
#           7         8         9
# 0  0.453719  0.887521  0.336367
# 1  0.474418  0.822153  0.215874
# 2  0.458556  0.498312  0.496434
# 3  0.451463  0.227612  0.375225
# 4  0.189524  0.843194  0.090184

# %%
random_df.shape
# Out:
# (20, 10)

# %%
#Inspecting a DataFrame

# %%
#finding the number of rows and columns

# %%
diabetes_df.shape
# Out:
# (442, 10)

# %%
#first 5 rows in a DataFrame

# %%
diabetes_df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019908 -0.017646
# 1 -0.039493 -0.068330 -0.092204
# 2 -0.002592  0.002864 -0.025930
# 3  0.034309  0.022692 -0.009362
# 4 -0.002592 -0.031991 -0.046641

# %%
#Last 5 rows of the DataFrame

# %%
diabetes_df.tail()
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017282 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081414  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 437 -0.002592  0.031193  0.007207
# 438  0.034309 -0.018118  0.044485
# 439 -0.011080 -0.046879  0.015491
# 440  0.026560  0.044528 -0.025930
# 441 -0.039493 -0.004220  0.003064

# %%
#information about the DataFrame

# %%
diabetes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     442 non-null    float64
#  1   sex     442 non-null    float64
#  2   bmi     442 non-null    float64
#  3   bp      442 non-null    float64
#  4   s1      442 non-null    float64
#  5   s2      442 non-null    float64
#  6   s3      442 non-null    float64
#  7   s4      442 non-null    float64
#  8   s5      442 non-null    float64
#  9   s6      442 non-null    float64
# dtypes: float64(10)
# memory usage: 34.7 KB

# %%
#finding the number of missing values

# %%
diabetes_df.isnull().sum()
# Out:
# age    0
# sex    0
# bmi    0
# bp     0
# s1     0
# s2     0
# s3     0
# s4     0
# s5     0
# s6     0
# dtype: int64

# %%
df1.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
#counting the values based on labels

# %%
df1.value_counts('Outcome')
# Out:
# Outcome
# 0    500
# 1    268
# dtype: int64

# %%
#Group the value based on the mean

# %%
df1.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
#Statistical Measures

# %%
#Count or number of values in each columns

# %%
diabetes_df.count()
# Out:
# age    442
# sex    442
# bmi    442
# bp     442
# s1     442
# s2     442
# s3     442
# s4     442
# s5     442
# s6     442
# dtype: int64

# %%
diabetes_df.mean()
# Out:
# age   -3.634285e-16
# sex    1.308343e-16
# bmi   -8.045349e-16
# bp     1.281655e-16
# s1    -8.835316e-17
# s2     1.327024e-16
# s3    -4.574646e-16
# s4     3.777301e-16
# s5    -3.830854e-16
# s6    -3.412882e-16
# dtype: float64

# %%
diabetes_df.std()
# Out:
# age    0.047619
# sex    0.047619
# bmi    0.047619
# bp     0.047619
# s1     0.047619
# s2     0.047619
# s3     0.047619
# s4     0.047619
# s5     0.047619
# s6     0.047619
# dtype: float64

# %%
diabetes_df.min()
# Out:
# age   -0.107226
# sex   -0.044642
# bmi   -0.090275
# bp    -0.112400
# s1    -0.126781
# s2    -0.115613
# s3    -0.102307
# s4    -0.076395
# s5    -0.126097
# s6    -0.137767
# dtype: float64

# %%
diabetes_df.max()
# Out:
# age    0.110727
# sex    0.050680
# bmi    0.170555
# bp     0.132044
# s1     0.153914
# s2     0.198788
# s3     0.181179
# s4     0.185234
# s5     0.133599
# s6     0.135612
# dtype: float64

# %%
#all the Statistical measure about the Data Frame

# %%
diabetes_df.describe()
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -3.634285e-16  1.308343e-16 -8.045349e-16  1.281655e-16 -8.835316e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123996e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665645e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670611e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564384e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320442e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   1.327024e-16 -4.574646e-16  3.777301e-16 -3.830854e-16 -3.412882e-16
# ...

# %%
#Manipullating a DataFrame

# %%
#Adding a column to a DataFrame

# %%
diabetes_df['label']=dibetes_db.target

# %%
diabetes_df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  label
# 0 -0.002592  0.019908 -0.017646  151.0
# 1 -0.039493 -0.068330 -0.092204   75.0
# 2 -0.002592  0.002864 -0.025930  141.0
# 3  0.034309  0.022692 -0.009362  206.0
# 4 -0.002592 -0.031991 -0.046641  135.0

# %%
#Removing a row

# %%
diabetes_df.drop(index=0,axis=0)
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# 5   -0.092695 -0.044642 -0.040696 -0.019442 -0.068991 -0.079288  0.041277
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017282 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081414  0.083740  0.027809  0.173816
#
#            s4        s5        s6  label
# ...

# %%
#Drop a columns
diabetes_df.drop(columns='label',axis=1)
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 0    0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3   -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# ..        ...       ...       ...       ...       ...       ...       ...
# 437  0.041708  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438 -0.005515  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  0.041708  0.050680 -0.015906  0.017282 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081414  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 0   -0.002592  0.019908 -0.017646
# ...

# %%
#locating a row using the index value

# %%
diabetes_df.iloc[2]
# Out:
# age        0.085299
# sex        0.050680
# bmi        0.044451
# bp        -0.005671
# s1        -0.045599
# s2        -0.034194
# s3        -0.032356
# s4        -0.002592
# s5         0.002864
# s6        -0.025930
# label    141.000000
# Name: 2, dtype: float64

# %%
#locating a particular column

# %%
diabetes_df.iloc[:,1] # second column
# Out:
# 0      0.050680
# 1     -0.044642
# 2      0.050680
# 3     -0.044642
# 4     -0.044642
#          ...
# 437    0.050680
# 438    0.050680
# 439    0.050680
# 440   -0.044642
# 441   -0.044642
# Name: sex, Length: 442, dtype: float64

# %% [markdown]
# Correlation
#
# 1.Positive Correlation
#
# 2.Negative Correlation

# %%
diabetes_df.corr()
# Out:
#             age       sex       bmi        bp        s1        s2        s3  \
# age    1.000000  0.173737  0.185085  0.335427  0.260061  0.219243 -0.075181
# sex    0.173737  1.000000  0.088161  0.241013  0.035277  0.142637 -0.379090
# bmi    0.185085  0.088161  1.000000  0.395415  0.249777  0.261170 -0.366811
# bp     0.335427  0.241013  0.395415  1.000000  0.242470  0.185558 -0.178761
# s1     0.260061  0.035277  0.249777  0.242470  1.000000  0.896663  0.051519
# s2     0.219243  0.142637  0.261170  0.185558  0.896663  1.000000 -0.196455
# s3    -0.075181 -0.379090 -0.366811 -0.178761  0.051519 -0.196455  1.000000
# s4     0.203841  0.332115  0.413807  0.257653  0.542207  0.659817 -0.738493
# s5     0.270777  0.149918  0.446159  0.393478  0.515501  0.318353 -0.398577
# s6     0.301731  0.208133  0.388680  0.390429  0.325717  0.290600 -0.273697
# label  0.187889  0.043062  0.586450  0.441484  0.212022  0.174054 -0.394789
#
#              s4        s5        s6     label
# ...
