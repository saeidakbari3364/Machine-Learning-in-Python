# %% [markdown]
# **Pandas Trick 07**
# <br></br>
# change name of columns

# %%
import numpy as np
import pandas as pd

# %%
pd.__version__
# Out:
# '2.1.4'

# %%
#Make DataFrame

# %%
pd.DataFrame(np.random.rand(5,10))
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.046827  0.906154  0.251235  0.182569  0.101478  0.118445  0.795587
# 1  0.429374  0.068019  0.252558  0.187199  0.402670  0.781332  0.627582
# 2  0.551293  0.494940  0.676236  0.509692  0.166215  0.930430  0.567663
# 3  0.839916  0.676152  0.032338  0.531536  0.228231  0.598585  0.909524
# 4  0.758214  0.758345  0.931684  0.155963  0.579589  0.147781  0.237159
#
#           7         8         9
# 0  0.687501  0.894251  0.357201
# 1  0.661541  0.020112  0.960349
# 2  0.569562  0.153115  0.434369
# 3  0.028037  0.523983  0.066788
# 4  0.541055  0.386815  0.413050

# %%
pd.DataFrame(np.random.rand(5,10),columns=list('ABCDEFGHJK'))
# Out:
#           A         B         C         D         E         F         G  \
# 0  0.198761  0.502463  0.104017  0.628625  0.379845  0.020131  0.355637
# 1  0.872490  0.009522  0.995418  0.690563  0.718636  0.834030  0.443136
# 2  0.734489  0.538091  0.849189  0.891731  0.899860  0.949331  0.111870
# 3  0.968678  0.961095  0.332733  0.396599  0.557380  0.092778  0.166186
# 4  0.921868  0.201578  0.851470  0.005965  0.045510  0.986971  0.184837
#
#           H         J         K
# 0  0.319061  0.822687  0.955881
# 1  0.998498  0.556571  0.650625
# 2  0.758544  0.243596  0.915508
# 3  0.270010  0.789221  0.297589
# 4  0.873235  0.292267  0.381752

# %%
#Another solution

# %%
df=pd.DataFrame({'column1':[10,20,30],'column2':[40,50,60]})
df.head()
# Out:
#    column1  column2
# 0       10       40
# 1       20       50
# 2       30       60

# %%
df=df.rename({'column1':'column_one','column2':'column_two'},axis='columns')
df.head()
# Out:
#    column_one  column_two
# 0          10          40
# 1          20          50
# 2          30          60

# %%
#Another way

# %%
df.columns=['col_one','col_two']

# %%
df.head()
# Out:
#    col_one  col_two
# 0       10       40
# 1       20       50
# 2       30       60

# %%
#other way

# %%
df.columns=df.columns.str.replace('_',' ')
df.head()
# Out:
#    col one  col two
# 0       10       40
# 1       20       50
# 2       30       60

# %%
df.add_prefix('X_')
# Out:
#    X_col one  X_col two
# 0         10         40
# 1         20         50
# 2         30         60

# %%
df.add_suffix('_Y')
# Out:
#    col one_Y  col two_Y
# 0         10         40
# 1         20         50
# 2         30         60
