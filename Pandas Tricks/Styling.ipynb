# %% [markdown]
# **Pandas Tricks**

# %% [markdown]
# Trick 05<br></br>
#
# Styling

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.1.4'

# %%
#Import Data and Make DataFrame

# %%
df=pd.read_csv('/content/drive/MyDrive/stocks.csv')
df.head()
# Out:
#          Date   Close    Volume Symbol
# 0  2016-10-03   31.50  14070500   CSCO
# 1  2016-10-03  112.52  21701800   AAPL
# 2  2016-10-03   57.42  19189500   MSFT
# 3  2016-10-04  113.00  29736800   AAPL
# 4  2016-10-04   57.24  20085900   MSFT

# %%
#Styling

# %%
df.columns
# Out:
# Index(['Date', 'Close', 'Volume', 'Symbol'], dtype='object')

# %%
formatter={'Close':'${:.2f}','Volume':'{:,}'}

# %%
df.style.format(formatter)
# Out:
# <style type="text/css">
# </style>
# <table id="T_23720" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_23720_level0_col0" class="col_heading level0 col0" >Date</th>
#       <th id="T_23720_level0_col1" class="col_heading level0 col1" >Close</th>
#       <th id="T_23720_level0_col2" class="col_heading level0 col2" >Volume</th>
#       <th id="T_23720_level0_col3" class="col_heading level0 col3" >Symbol</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23720_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_23720_row0_col0" class="data row0 col0" >2016-10-03</td>
#       <td id="T_23720_row0_col1" class="data row0 col1" >$31.50</td>
#       <td id="T_23720_row0_col2" class="data row0 col2" >14,070,500</td>
#       <td id="T_23720_row0_col3" class="data row0 col3" >CSCO</td>
#     </tr>
#     <tr>
#       <th id="T_23720_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_23720_row1_col0" class="data row1 col0" >2016-10-03</td>
#       <td id="T_23720_row1_col1" class="data row1 col1" >$112.52</td>
#       <td id="T_23720_row1_col2" class="data row1 col2" >21,701,800</td>
#       <td id="T_23720_row1_col3" class="data row1 col3" >AAPL</td>
#     </tr>
#     <tr>
#       <th id="T_23720_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_23720_row2_col0" class="data row2 col0" >2016-10-03</td>
#       <td id="T_23720_row2_col1" class="data row2 col1" >$57.42</td>
#       <td id="T_23720_row2_col2" class="data row2 col2" >19,189,500</td>
#       <td id="T_23720_row2_col3" class="data row2 col3" >MSFT</td>
#     </tr>
#     <tr>
#       <th id="T_23720_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_23720_row3_col0" class="data row3 col0" >2016-10-04</td>
#       <td id="T_23720_row3_col1" class="data row3 col1" >$113.00</td>
#       <td id="T_23720_row3_col2" class="data row3 col2" >29,736,800</td>
#       <td id="T_23720_row3_col3" class="data row3 col3" >AAPL</td>
#     </tr>
#     <tr>
#       <th id="T_23720_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_23720_row4_col0" class="data row4 col0" >2016-10-04</td>
#       <td id="T_23720_row4_col1" class="data row4 col1" >$57.24</td>
#       <td id="T_23720_row4_col2" class="data row4 col2" >20,085,900</td>
#       <td id="T_23720_row4_col3" class="data row4 col3" >MSFT</td>
#     </tr>
#     <tr>
#       <th id="T_23720_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_23720_row5_col0" class="data row5 col0" >2016-10-04</td>
#       <td id="T_23720_row5_col1" class="data row5 col1" >$31.35</td>
#       <td id="T_23720_row5_col2" class="data row5 col2" >18,460,400</td>
#       <td id="T_23720_row5_col3" class="data row5 col3" >CSCO</td>
#     </tr>
#     <tr>
#       <th id="T_23720_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_23720_row6_col0" class="data row6 col0" >2016-10-05</td>
#       <td id="T_23720_row6_col1" class="data row6 col1" >$57.64</td>
#       <td id="T_23720_row6_col2" class="data row6 col2" >16,726,400</td>
#       <td id="T_23720_row6_col3" class="data row6 col3" >MSFT</td>
#     </tr>
#     <tr>
#       <th id="T_23720_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_23720_row7_col0" class="data row7 col0" >2016-10-05</td>
#       <td id="T_23720_row7_col1" class="data row7 col1" >$31.59</td>
#       <td id="T_23720_row7_col2" class="data row7 col2" >11,808,600</td>
#       <td id="T_23720_row7_col3" class="data row7 col3" >CSCO</td>
#     </tr>
#     <tr>
#       <th id="T_23720_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_23720_row8_col0" class="data row8 col0" >2016-10-05</td>
#       <td id="T_23720_row8_col1" class="data row8 col1" >$113.05</td>
#       <td id="T_23720_row8_col2" class="data row8 col2" >21,453,100</td>
#       <td id="T_23720_row8_col3" class="data row8 col3" >AAPL</td>
#     </tr>
#   </tbody>
# </table>

# %%
(df.style.format(formatter)
.hide()
.highlight_min('Close',color='red')
.highlight_max('Close',color='lightgreen')
)
# Out:
# <style type="text/css">
# #T_8a2a8_row5_col1 {
#   background-color: red;
# }
# #T_8a2a8_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_8a2a8" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_8a2a8_level0_col0" class="col_heading level0 col0" >Date</th>
#       <th id="T_8a2a8_level0_col1" class="col_heading level0 col1" >Close</th>
#       <th id="T_8a2a8_level0_col2" class="col_heading level0 col2" >Volume</th>
#       <th id="T_8a2a8_level0_col3" class="col_heading level0 col3" >Symbol</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8a2a8_row0_col0" class="data row0 col0" >2016-10-03</td>
#       <td id="T_8a2a8_row0_col1" class="data row0 col1" >$31.50</td>
#       <td id="T_8a2a8_row0_col2" class="data row0 col2" >14,070,500</td>
#       <td id="T_8a2a8_row0_col3" class="data row0 col3" >CSCO</td>
#     </tr>
#     <tr>
#       <td id="T_8a2a8_row1_col0" class="data row1 col0" >2016-10-03</td>
#       <td id="T_8a2a8_row1_col1" class="data row1 col1" >$112.52</td>
#       <td id="T_8a2a8_row1_col2" class="data row1 col2" >21,701,800</td>
#       <td id="T_8a2a8_row1_col3" class="data row1 col3" >AAPL</td>
#     </tr>
#     <tr>
#       <td id="T_8a2a8_row2_col0" class="data row2 col0" >2016-10-03</td>
#       <td id="T_8a2a8_row2_col1" class="data row2 col1" >$57.42</td>
#       <td id="T_8a2a8_row2_col2" class="data row2 col2" >19,189,500</td>
#       <td id="T_8a2a8_row2_col3" class="data row2 col3" >MSFT</td>
#     </tr>
#     <tr>
#       <td id="T_8a2a8_row3_col0" class="data row3 col0" >2016-10-04</td>
#       <td id="T_8a2a8_row3_col1" class="data row3 col1" >$113.00</td>
#       <td id="T_8a2a8_row3_col2" class="data row3 col2" >29,736,800</td>
#       <td id="T_8a2a8_row3_col3" class="data row3 col3" >AAPL</td>
#     </tr>
#     <tr>
#       <td id="T_8a2a8_row4_col0" class="data row4 col0" >2016-10-04</td>
#       <td id="T_8a2a8_row4_col1" class="data row4 col1" >$57.24</td>
#       <td id="T_8a2a8_row4_col2" class="data row4 col2" >20,085,900</td>
#       <td id="T_8a2a8_row4_col3" class="data row4 col3" >MSFT</td>
#     </tr>
#     <tr>
#       <td id="T_8a2a8_row5_col0" class="data row5 col0" >2016-10-04</td>
#       <td id="T_8a2a8_row5_col1" class="data row5 col1" >$31.35</td>
#       <td id="T_8a2a8_row5_col2" class="data row5 col2" >18,460,400</td>
#       <td id="T_8a2a8_row5_col3" class="data row5 col3" >CSCO</td>
#     </tr>
#     <tr>
#       <td id="T_8a2a8_row6_col0" class="data row6 col0" >2016-10-05</td>
#       <td id="T_8a2a8_row6_col1" class="data row6 col1" >$57.64</td>
#       <td id="T_8a2a8_row6_col2" class="data row6 col2" >16,726,400</td>
#       <td id="T_8a2a8_row6_col3" class="data row6 col3" >MSFT</td>
#     </tr>
#     <tr>
#       <td id="T_8a2a8_row7_col0" class="data row7 col0" >2016-10-05</td>
#       <td id="T_8a2a8_row7_col1" class="data row7 col1" >$31.59</td>
#       <td id="T_8a2a8_row7_col2" class="data row7 col2" >11,808,600</td>
#       <td id="T_8a2a8_row7_col3" class="data row7 col3" >CSCO</td>
#     </tr>
#     <tr>
#       <td id="T_8a2a8_row8_col0" class="data row8 col0" >2016-10-05</td>
#       <td id="T_8a2a8_row8_col1" class="data row8 col1" >$113.05</td>
#       <td id="T_8a2a8_row8_col2" class="data row8 col2" >21,453,100</td>
#       <td id="T_8a2a8_row8_col3" class="data row8 col3" >AAPL</td>
#     </tr>
#   </tbody>
# </table>

# %%
(df.style.format(formatter)
.hide()
.background_gradient(subset='Volume',cmap='Blues')
)
# Out:
# <style type="text/css">
# #T_961d6_row0_col2 {
#   background-color: #deebf7;
#   color: #000000;
# }
# #T_961d6_row1_col2 {
#   background-color: #5aa2cf;
#   color: #f1f1f1;
# }
# #T_961d6_row2_col2 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_961d6_row3_col2 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_961d6_row4_col2 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_961d6_row5_col2 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_961d6_row6_col2 {
#   background-color: #bed8ec;
#   color: #000000;
# }
# #T_961d6_row7_col2 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_961d6_row8_col2 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_961d6" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_961d6_level0_col0" class="col_heading level0 col0" >Date</th>
#       <th id="T_961d6_level0_col1" class="col_heading level0 col1" >Close</th>
#       <th id="T_961d6_level0_col2" class="col_heading level0 col2" >Volume</th>
#       <th id="T_961d6_level0_col3" class="col_heading level0 col3" >Symbol</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_961d6_row0_col0" class="data row0 col0" >2016-10-03</td>
#       <td id="T_961d6_row0_col1" class="data row0 col1" >$31.50</td>
#       <td id="T_961d6_row0_col2" class="data row0 col2" >14,070,500</td>
#       <td id="T_961d6_row0_col3" class="data row0 col3" >CSCO</td>
#     </tr>
#     <tr>
#       <td id="T_961d6_row1_col0" class="data row1 col0" >2016-10-03</td>
#       <td id="T_961d6_row1_col1" class="data row1 col1" >$112.52</td>
#       <td id="T_961d6_row1_col2" class="data row1 col2" >21,701,800</td>
#       <td id="T_961d6_row1_col3" class="data row1 col3" >AAPL</td>
#     </tr>
#     <tr>
#       <td id="T_961d6_row2_col0" class="data row2 col0" >2016-10-03</td>
#       <td id="T_961d6_row2_col1" class="data row2 col1" >$57.42</td>
#       <td id="T_961d6_row2_col2" class="data row2 col2" >19,189,500</td>
#       <td id="T_961d6_row2_col3" class="data row2 col3" >MSFT</td>
#     </tr>
#     <tr>
#       <td id="T_961d6_row3_col0" class="data row3 col0" >2016-10-04</td>
#       <td id="T_961d6_row3_col1" class="data row3 col1" >$113.00</td>
#       <td id="T_961d6_row3_col2" class="data row3 col2" >29,736,800</td>
#       <td id="T_961d6_row3_col3" class="data row3 col3" >AAPL</td>
#     </tr>
#     <tr>
#       <td id="T_961d6_row4_col0" class="data row4 col0" >2016-10-04</td>
#       <td id="T_961d6_row4_col1" class="data row4 col1" >$57.24</td>
#       <td id="T_961d6_row4_col2" class="data row4 col2" >20,085,900</td>
#       <td id="T_961d6_row4_col3" class="data row4 col3" >MSFT</td>
#     </tr>
#     <tr>
#       <td id="T_961d6_row5_col0" class="data row5 col0" >2016-10-04</td>
#       <td id="T_961d6_row5_col1" class="data row5 col1" >$31.35</td>
#       <td id="T_961d6_row5_col2" class="data row5 col2" >18,460,400</td>
#       <td id="T_961d6_row5_col3" class="data row5 col3" >CSCO</td>
#     </tr>
#     <tr>
#       <td id="T_961d6_row6_col0" class="data row6 col0" >2016-10-05</td>
#       <td id="T_961d6_row6_col1" class="data row6 col1" >$57.64</td>
#       <td id="T_961d6_row6_col2" class="data row6 col2" >16,726,400</td>
#       <td id="T_961d6_row6_col3" class="data row6 col3" >MSFT</td>
#     </tr>
#     <tr>
#       <td id="T_961d6_row7_col0" class="data row7 col0" >2016-10-05</td>
#       <td id="T_961d6_row7_col1" class="data row7 col1" >$31.59</td>
#       <td id="T_961d6_row7_col2" class="data row7 col2" >11,808,600</td>
#       <td id="T_961d6_row7_col3" class="data row7 col3" >CSCO</td>
#     </tr>
#     <tr>
#       <td id="T_961d6_row8_col0" class="data row8 col0" >2016-10-05</td>
#       <td id="T_961d6_row8_col1" class="data row8 col1" >$113.05</td>
#       <td id="T_961d6_row8_col2" class="data row8 col2" >21,453,100</td>
#       <td id="T_961d6_row8_col3" class="data row8 col3" >AAPL</td>
#     </tr>
#   </tbody>
# </table>

# %%
(df.style.format(formatter)
.hide()
.bar('Volume',color='lightblue',align='zero')
.set_caption('Stock Prices from October 2016'))
# Out:
# <style type="text/css">
# #T_8819a_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 73.7%, transparent 73.7%);
# }
# #T_8819a_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 86.5%, transparent 86.5%);
# }
# #T_8819a_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 82.3%, transparent 82.3%);
# }
# #T_8819a_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 100.0%, transparent 100.0%);
# }
# #T_8819a_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 83.8%, transparent 83.8%);
# }
# #T_8819a_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 81.0%, transparent 81.0%);
# }
# #T_8819a_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 78.1%, transparent 78.1%);
# }
# #T_8819a_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 69.9%, transparent 69.9%);
# }
# #T_8819a_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, transparent 50.0%, lightblue 50.0%, lightblue 86.1%, transparent 86.1%);
# }
# </style>
# <table id="T_8819a" class="dataframe">
#   <caption>Stock Prices from October 2016</caption>
#   <thead>
#     <tr>
#       <th id="T_8819a_level0_col0" class="col_heading level0 col0" >Date</th>
#       <th id="T_8819a_level0_col1" class="col_heading level0 col1" >Close</th>
#       <th id="T_8819a_level0_col2" class="col_heading level0 col2" >Volume</th>
#       <th id="T_8819a_level0_col3" class="col_heading level0 col3" >Symbol</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_8819a_row0_col0" class="data row0 col0" >2016-10-03</td>
#       <td id="T_8819a_row0_col1" class="data row0 col1" >$31.50</td>
#       <td id="T_8819a_row0_col2" class="data row0 col2" >14,070,500</td>
#       <td id="T_8819a_row0_col3" class="data row0 col3" >CSCO</td>
#     </tr>
#     <tr>
#       <td id="T_8819a_row1_col0" class="data row1 col0" >2016-10-03</td>
#       <td id="T_8819a_row1_col1" class="data row1 col1" >$112.52</td>
#       <td id="T_8819a_row1_col2" class="data row1 col2" >21,701,800</td>
#       <td id="T_8819a_row1_col3" class="data row1 col3" >AAPL</td>
#     </tr>
#     <tr>
#       <td id="T_8819a_row2_col0" class="data row2 col0" >2016-10-03</td>
#       <td id="T_8819a_row2_col1" class="data row2 col1" >$57.42</td>
#       <td id="T_8819a_row2_col2" class="data row2 col2" >19,189,500</td>
#       <td id="T_8819a_row2_col3" class="data row2 col3" >MSFT</td>
#     </tr>
#     <tr>
#       <td id="T_8819a_row3_col0" class="data row3 col0" >2016-10-04</td>
#       <td id="T_8819a_row3_col1" class="data row3 col1" >$113.00</td>
#       <td id="T_8819a_row3_col2" class="data row3 col2" >29,736,800</td>
#       <td id="T_8819a_row3_col3" class="data row3 col3" >AAPL</td>
#     </tr>
#     <tr>
#       <td id="T_8819a_row4_col0" class="data row4 col0" >2016-10-04</td>
#       <td id="T_8819a_row4_col1" class="data row4 col1" >$57.24</td>
#       <td id="T_8819a_row4_col2" class="data row4 col2" >20,085,900</td>
#       <td id="T_8819a_row4_col3" class="data row4 col3" >MSFT</td>
#     </tr>
#     <tr>
#       <td id="T_8819a_row5_col0" class="data row5 col0" >2016-10-04</td>
#       <td id="T_8819a_row5_col1" class="data row5 col1" >$31.35</td>
#       <td id="T_8819a_row5_col2" class="data row5 col2" >18,460,400</td>
#       <td id="T_8819a_row5_col3" class="data row5 col3" >CSCO</td>
#     </tr>
#     <tr>
#       <td id="T_8819a_row6_col0" class="data row6 col0" >2016-10-05</td>
#       <td id="T_8819a_row6_col1" class="data row6 col1" >$57.64</td>
#       <td id="T_8819a_row6_col2" class="data row6 col2" >16,726,400</td>
#       <td id="T_8819a_row6_col3" class="data row6 col3" >MSFT</td>
#     </tr>
#     <tr>
#       <td id="T_8819a_row7_col0" class="data row7 col0" >2016-10-05</td>
#       <td id="T_8819a_row7_col1" class="data row7 col1" >$31.59</td>
#       <td id="T_8819a_row7_col2" class="data row7 col2" >11,808,600</td>
#       <td id="T_8819a_row7_col3" class="data row7 col3" >CSCO</td>
#     </tr>
#     <tr>
#       <td id="T_8819a_row8_col0" class="data row8 col0" >2016-10-05</td>
#       <td id="T_8819a_row8_col1" class="data row8 col1" >$113.05</td>
#       <td id="T_8819a_row8_col2" class="data row8 col2" >21,453,100</td>
#       <td id="T_8819a_row8_col3" class="data row8 col3" >AAPL</td>
#     </tr>
#   </tbody>
# </table>
