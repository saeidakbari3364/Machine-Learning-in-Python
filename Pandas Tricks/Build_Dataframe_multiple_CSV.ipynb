# %%
#Trick 14
#how to build datafarame from multiple csv files

# %%
import pandas as pd

# %%
pd.read_csv('/content/drive/MyDrive/Churn_Modelling_1.csv')
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
# 5          6    15574012       Chu          645     Spain    Male   44
# 6          7    15592531  Bartlett          822    France    Male   50
# 7          8    15656148    Obinna          376   Germany  Female   29
# 8          9    15792365        He          501    France    Male   44
# 9         10    15592389        H?          684    France    Male   27
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# ...

# %%
pd.read_csv('/content/drive/MyDrive/Churn_Modelling_2.csv')
# Out:
#    RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0         11    15767821     Bearce          528    France    Male   31
# 1         12    15737173    Andrews          497     Spain    Male   24
# 2         13    15632264        Kay          476    France  Female   34
# 3         14    15691483       Chin          549    France  Female   25
# 4         15    15600882      Scott          635     Spain  Female   35
# 5         16    15643966    Goforth          616   Germany    Male   45
# 6         17    15737452      Romeo          653   Germany    Male   58
# 7         18    15788218  Henderson          549     Spain  Female   24
# 8         19    15661507    Muldrow          587     Spain    Male   45
# 9         20    15568982        Hao          726    France  Female   24
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       6  102016.72              2          0               0
# ...

# %%
pd.read_csv('/content/drive/MyDrive/Churn_Modelling_3.csv')
# Out:
#    RowNumber  CustomerId     Surname  CreditScore Geography  Gender  Age  \
# 0         21    15577657    McDonald          732    France    Male   41
# 1         22    15597945    Dellucci          636     Spain  Female   32
# 2         23    15699309   Gerasimov          510     Spain  Female   38
# 3         24    15725737      Mosman          669    France    Male   46
# 4         25    15625047         Yen          846    France  Female   38
# 5         26    15738191     Maclean          577    France    Male   25
# 6         27    15736816       Young          756   Germany    Male   36
# 7         28    15700772     Nebechi          571    France    Male   44
# 8         29    15728693  McWilliams          574   Germany  Female   43
# 9         30    15656300    Lucciano          411    France    Male   29
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       8       0.00              2          1               1
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from glob import glob

# %%
churn_files=sorted(glob('/content/drive/MyDrive/Churn_Modelling_*.csv'))
churn_files
# Out:
# ['/content/drive/MyDrive/Churn_Modelling_1.csv',
#  '/content/drive/MyDrive/Churn_Modelling_2.csv',
#  '/content/drive/MyDrive/Churn_Modelling_3.csv',
#  '/content/drive/MyDrive/Churn_Modelling_OLJMTbt.csv']

# %%
pd.concat(pd.read_csv(file) for file in churn_files)
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
pd.concat((pd.read_csv(file) for file in churn_files),ignore_index=True)
# Out:
#        RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0              1    15634602   Hargrave          619    France  Female   42
# 1              2    15647311       Hill          608     Spain  Female   41
# 2              3    15619304       Onio          502    France  Female   42
# 3              4    15701354       Boni          699    France  Female   39
# 4              5    15737888   Mitchell          850     Spain  Female   43
# ...          ...         ...        ...          ...       ...     ...  ...
# 10025       9996    15606229   Obijiaku          771    France    Male   39
# 10026       9997    15569892  Johnstone          516    France    Male   35
# 10027       9998    15584532        Liu          709    France  Female   36
# 10028       9999    15682355  Sabbatini          772   Germany    Male   42
# 10029      10000    15628319     Walker          792    France  Female   28
#
# ...
